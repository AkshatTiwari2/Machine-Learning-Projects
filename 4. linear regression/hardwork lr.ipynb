# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/linear regression/Training Data (1)/Linear_X_Train.csv')
Y = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/linear regression/Training Data (1)/Linear_Y_Train.csv')

X = X.values
Y = Y.values

u = X.mean()
std = X.std()

X = (X-u)/std

plt.style.use('seaborn-v0_8')
plt.scatter(X,Y,color = 'orange')
plt.title("Hardwork vs Performance Graph")
plt.xlabel("Hardwork")
plt.ylabel("Performance")
plt.show()
X.shape,Y.shape
# Out:
# ((3750, 1), (3750, 1))

# %%
def hypothesis(x,theta):
  y_ = theta[0]+theta[1]*x
  return y_

def gradient(x,y,theta):
  m = x.shape[0]
  grad = np.zeros((2,))
  y_ = hypothesis(x,theta)
  for i in range(m):
    grad[0] += y_[i]-y[i]
    grad[1] += (y_[i]-y[i])*x[i]
  return grad/m

def error(x, y, theta):
    y_ = hypothesis(x, theta)      # One call for all x
    m = x.shape[0]
    error = 0
    for i in range(m):
        error += (y_[i] - y[i]) ** 2
    return error / m


def gradient_descent(X,Y,max_steps=100,lr=0.1):
  theta = np.zeros((2,))
  error_list = []
  theta_list = []

  for i in range(max_steps):
    grad = gradient(X,Y,theta)
    e = error(X,Y,theta)[0]
    error_list.append(e)
    theta[0] = theta[0] - lr*grad[0]
    theta[1] = theta[1] - lr*grad[1]
    theta_list.append((theta[0],theta[1]))
  return theta,error_list,theta_list

# %%
theta,error_list,theta_list = gradient_descent(X,Y)
# Out:
# /tmp/ipython-input-3-3463425211.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   grad[0] += y_[i]-y[i]
# /tmp/ipython-input-3-3463425211.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   grad[1] += (y_[i]-y[i])*x[i]

# %%
plt.plot(error_list)
plt.title("Reduction error over time")
plt.show()

# %%
y_ = hypothesis(X,theta)

# %%
plt.scatter(X,Y,color = 'orange')
plt.plot(X,y_,label = "Prediction")
plt.legend()
plt.show()

# %%
X_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/linear regression/Test Cases (1)/Linear_X_Test.csv").values
y_test = hypothesis(X_test,theta)

y_test.shape
# Out:
# (1250, 1)

# %%
df = pd.DataFrame(y_test,columns=["y"])

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/linear regression/Training Data (1)/y_prediction.csv',index = False)

# %%
df
# Out:
#                y
# 0    -149.370696
# 1     -68.754940
# 2    -201.486870
# 3     221.234243
# 4      47.906897
# ...          ...
# 1245  -12.744630
# 1246   75.171802
# 1247   10.912138
# 1248  -21.532358
# 1249  -53.684600
#
# [1250 rows x 1 columns]

# %%
y_test
# Out:
# array([[-149.37069577],
#        [ -68.75494042],
#        [-201.48687035],
#        ...,
#        [  10.9121384 ],
#        [ -21.53235759],
#        [ -53.68460035]])

# %%
X_test
# Out:
# array([[-1.87794441],
#        [-0.86903192],
#        [-2.53018242],
#        ...,
#        [ 0.12800782],
#        [-0.27803759],
#        [-0.68042543]])

# %%
def r2score(y,y_):
  num = np.sum((y-y_)**2)
  denom = np.sum((y-y.mean())**2)
  score = 1 - num/denom
  return score*100

# %%
r2score(Y,y_)
# Out:
# np.float64(97.09612226971643)

# %%
a = [1,2,3]
b = [4,5,6,7]
a,b = np.meshgrid(a,b)

# %%
theta
# Out:
# array([ 0.6838508 , 79.90361453])

# %%
T0 = np.arange(-40,40)
T1 = np.arange(40,120)
T0,T1 = np.meshgrid(T0,T1)

# %%
m = X.shape[0]
J = np.zeros(T0.shape)
for i in range(J.shape[0]):
  for j in range(J.shape[1]):
    y_ = T1[i,j]*X+T0[i,j]
    J[i][j] = np.sum((Y-y_)**2)/m

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
axes = fig.add_subplot(111,projection = '3d')
axes.plot_surface(T0,T1,J,cmap = 'rainbow')
axes.scatter(theta_list[:,0],theta_list[:,1],error_list)
plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(111,projection = '3d')
axes.contour(T0,T1,J,cmap = 'rainbow')
axes.scatter(theta_list[:,0],theta_list[:,1],error_list)
plt.show()

# %%
plt.contour(T0,T1,J,cmap = "rainbow")
plt.scatter(theta_list[:,0],theta_list[:,1])
plt.show()

# %%
T0 = theta_list[:,0]
T1 = theta_list[:,1]

# %%
theta_list = np.array(theta_list)
plt.plot(theta_list[:,0],label = "T0")
plt.plot(theta_list[:,1],label = "T1")
plt.legend()
plt.show()

# %% [markdown]
# ### With random data 3d

# %%
import numpy as np
import matplotlib.pyplot as plt


a = np.arange(-1,1,0.02)
b = a
a, b = np.meshgrid(a, b)

fig = plt.figure()
axes = fig.add_subplot(111, projection='3d')  # ✅ Correct way to get 3D axes
axes.plot_surface(a, b, a**2 + b**2,cmap = 'rainbow')

plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(111, projection='3d')
axes.contour(a, b, a**2 + b**2,cmap = 'rainbow')
plt.show()

# %%
import numpy as np
a = np.array([[2],[3]])
b = np.array([2,3])

# %%
np.dot(np.transpose(a),b)
# Out:
# array([13])

# %%
a = np.zeros((2))

# %%
a
# Out:
# array([[2],
#        [3]])

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(2,1,1)
plt.plot(a)
plt.subplot(2,1,2)
plt.plot(b)
plt.show()

# %%
a = np.array([1,2,3])
b = [1,2,3]
